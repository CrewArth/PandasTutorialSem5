# %%
import pandas as pd

df = pd.read_csv('Dataset.csv') #This will access the file and read the data.

df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
#To Find the total Duplicate Records.

Duplicate_Records = df.duplicated(subset='customerID').sum()

print(Duplicate_Records)
# Out:
# 0

# %%
#To Find missing values of a variable.

Missing_Values = df['tenure'].isnull().sum()

print(Missing_Values)
# Out:
# 0

# %%
#To get multiple Series.

das = df[['customerID','PaymentMethod']]
das.head(10)
# Out:
#    customerID              PaymentMethod
# 0  7590-VHVEG           Electronic check
# 1  5575-GNVDE               Mailed check
# 2  3668-QPYBK               Mailed check
# 3  7795-CFOCW  Bank transfer (automatic)
# 4  9237-HQITU           Electronic check
# 5  9305-CDSKC           Electronic check
# 6  1452-KIOVK    Credit card (automatic)
# 7  6713-OKOMC               Mailed check
# 8  7892-POOKP           Electronic check
# 9  6388-TABGU  Bank transfer (automatic)

# %%
#Calculate Avereage Monthly Charge

Avg = df['MonthlyCharges'].mean()
print(f"The Average of Month Charges is {Avg}")
# Out:
# The Average of Month Charges is 64.76169246059918

# %%
#Count records which has '#@$' or search something

Count = (df['InternetService'] == 'DSL').sum()
print(f"DataFrame contains {Count} DSL's")
# Out:
# DataFrame contains 2421 DSL's

# %%
#Count Duplicate records in customerID

dup_cid = df.duplicated(subset='customerID').sum()
print(f"Duplicate Records in Customer ID are {dup_cid}")
# Out:
# Duplicate Records in Customer ID are 0
